# %%
from PIL import Image
import numpy as np
from iminuit import Minuit


import matplotlib

import matplotlib.pyplot as plt

matplotlib.rcParams['figure.figsize'] = (16, 10)
matplotlib.rcParams.update({'font.size': 18})

# %%
# img = Image.open('demo/ocean_pano.jpg')
img = Image.open('demo/beach-ocean-panorama-187916.jpg')

# %%
plt.imshow(img)
plt.axvline(x=2000)
plt.axvline(x=8000)
plt.show()

# %%
arry = img.getdata()

# %%
im_arr = np.fromstring(img.tobytes(), dtype=np.uint8)
im_arr = im_arr.reshape((img.size[1], img.size[0], 3))
# Out:
# /var/folders/bt/hcx3fsms41nfk08g1d3xy8t40000gn/T/ipykernel_31802/3829475553.py:1: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   im_arr = np.fromstring(img.tobytes(), dtype=np.uint8)

# %%
plt.imshow(im_arr)
plt.show()

# %%
from sklearn.cluster import KMeans, MiniBatchKMeans

# %%
pix_list = im_arr.reshape((im_arr.shape[0] * im_arr.shape[1], im_arr.shape[2]))

# %%
pix_list.shape
# Out:
# (17408000, 3)

# %%
km = KMeans(n_clusters=2)
km.fit(pix_list[::10])
# Out:
# KMeans(n_clusters=2)

# %%
classed = km.predict(pix_list)

# %%
recon = classed.reshape(im_arr.shape[:2])

# %%
plt.imshow(recon)
plt.show()

# %%
grad = np.log10(abs(np.gradient(im_arr.sum(axis=2), axis=0)))
grad[np.isinf(grad)] = 0
plt.imshow(grad)
# plt.colorbar()
plt.show()
# Out:
# /var/folders/bt/hcx3fsms41nfk08g1d3xy8t40000gn/T/ipykernel_47054/2546945504.py:1: RuntimeWarning: divide by zero encountered in log10
#   grad = np.log10(abs(np.gradient(im_arr.sum(axis=2), axis=0)))

# %%
from scipy.signal import savgol_filter

# %%
grad.shape[0], y.shape
# Out:
# (2832, (2832, 4256))

# %%
y = grad[:, 2000]
y[np.isinf(y)] = 0

yhat = savgol_filter(y, 101, 3)

yhathat = np.diff(yhat)
m = np.argmax(yhathat)

plt.axvline(x=m, c='y', ls='--')

plt.scatter(np.arange(grad.shape[0]), y)
plt.plot(np.arange(grad.shape[0]), yhat, c='k')

plt.show()

# %%
# def find_break(image, buffer=1500):
    
#     breaks = []
#     for i in range(image.shape[1]):
    
#         y = grad[:, i]
#         y[np.isinf(y)] = 0

#         yhat = savgol_filter(y, 101, 3)

#         yhathat = np.diff(yhat)
#         m = np.argmax(yhathat[buffer:-(buffer+300)])
# #         m = np.argmax(yhathat)

#         breaks += [m+buffer]
        
#     return np.array(breaks)

def find_break(image, y_min=0, y_max=-1):        
    
    breaks = []
    for i in range(image.shape[1]):
    
        y = grad[:, i]
        y[np.isinf(y)] = 0

        yhat = savgol_filter(y, 101, 3)

        yhathat = np.diff(yhat)
        m = np.argmax(yhathat[y_min:y_max])
#         m = np.argmax(yhathat)

        breaks += [m+y_min]
        
    return np.array(breaks)

# breaks = find_break(grad)
# breaks = find_break(grad, y_min=1510, y_max=1550)

# %%
# plt.imshow(grad)
plt.plot(np.arange(grad.shape[1]), breaks)
plt.show()

# %%
y = breaks.copy()

# yhat = savgol_filter(y, 901, 1)
yhat = savgol_filter(y, 301, 1)


plt.scatter(np.arange(grad.shape[1]), y)
plt.plot(np.arange(grad.shape[1]), yhat, c='k')

plt.show()

# %%
# cut = breaks[(breaks < 1920) & (breaks > 1780)][2000:8000]
cut = breaks[:6000]
plt.scatter(np.arange(len(cut)), cut)
plt.show()

# %%
cut = breaks

# %%
plt.imshow(grad)
coeff, cov = np.polyfit(np.arange(len(cut)), cut, 2, cov=True)
# coeff[0] = 0
coeff = [2e-6, -1.15e-2, 1.532e3]
y_fit = np.poly1d(coeff)(np.arange(len(cut)))

# plt.scatter(np.arange(len(cut))+2000, cut)
# plt.plot(np.arange(len(cut))+2000, y_fit, c='k', lw=4)
plt.plot(np.arange(len(cut)), y_fit, c='k', lw=4)
plt.show()

# %%
coeff
# Out:
# array([ 6.29329456e-07, -3.91791683e-03,  1.53037289e+03])

# %%
plt.scatter(np.arange(len(cut)), cut)
# plt.plot(np.arange(len(cut)), y_fit, c='k', lw=4)
plt.plot(np.arange(len(cut)), np.poly1d([2e-6, -1.15e-2, 1.532e3])(np.arange(len(cut))), c='k', lw=4)
plt.show()

# %%
coeff, cov
# Out:
# (array([ 6.29329456e-07, -3.91791683e-03,  1.53037289e+03]),
#  array([[ 2.43670382e-15, -1.46177862e-11,  1.46129136e-08],
#         [-1.46177862e-11,  9.35401880e-08, -1.05204210e-04],
#         [ 1.46129136e-08, -1.05204210e-04,  1.57793167e-01]]))

# %%
grad.shape[0] - coeff[-1]
# Out:
# 594.6271074008232

# %%
flat = coeff.copy()
flat[1] = 0
flat[2] = 0
y_fit = np.poly1d(flat)(np.arange(len(cut)))

plt.plot(np.arange(len(cut)), y_fit, c='k')
plt.show()

# %%
# number of pixels lost over the fit range with just the curvature component
min(y_fit)
max(y_fit)
# Out:
# 71.976002

# %%
# if we are losing 35 for every 6k pixels, we just need to know how far 6k pixels is

# %%
# easy to get how many pixels it takes to go round the world, but km?

# %%
th = np.tan(abs(max(abs(y_fit)) / len(y_fit)))
th
# Out:
# 0.011996575790697555

# %%
angle = th / 6000

# %%
coords, circ = step_rad(stepsize=50, angle=angle)
print(circ)

plt.scatter(coords[:, 0], coords[:, 1])
plt.show()
# Out:
# 26300

# %%
th = np.arctan(0.006)
th
# Out:
# 0.00599992800155516

# %%
0.006*5 * np.sin(th)
# Out:
# 0.0001799967600874774

# %%
th*20 * np.sin(th)
# Out:
# 0.0007002895853529242

# %%
6000 * 1e-6
# Out:
# 0.006

# %%
def step_rad(stepsize=5, angle=1e-6):
    
    d1 = 6000 * angle
    
    dev = d1 * stepsize
    
    coords = [[0, 0]]
    adj = coords[-1].copy()
    adj[0] -= stepsize
    adj[1] -= dev
    coords += [adj]
        
#     for i in range(1, n_steps):
        
    i = 0
    while coords[-1][0] < 0:
        i += 1
        prev = coords[i - 1].copy()
        current = coords[i].copy()
        dy = (current[1] - prev[1])
        dx = (current[0] - prev[0])
        
        midpoint = [prev[0] + 2*dx, prev[1] + 2*dy]
        
        m = dy / dx
        a = -1. / m
        
        th = np.arctan(a)
        dy2 = dev * np.sin(th)
        dx2 = dev * np.cos(th)
        
        next_point = [midpoint[0] + dx2, midpoint[1] + dy2]
        
        coords += [next_point]
    
    return np.array(coords), len(coords) * stepsize * 2

coords, circ = step_rad(stepsize=5, angle=1.01e-6)
print(circ)
coords, circ = step_rad(stepsize=20, angle=0.99e-6)
print(circ)

plt.scatter(coords[:, 0], coords[:, 1])
plt.show()
# Out:
# 5190
# 21200

# %%
def intrinsic_transform(world_coords, f=1, px=1, py=1, x0=0, y0=0):
    Mi = np.array([
        [float(f)/px, 0, x0, 0],
        [0, float(f)/py, y0, 0],
        [0, 0, 1, 0]
    ])
        
    # todo allow for shear/etc.    
    
    camera_coords = []
    for i in range(len(world_coords)):
        camera_coords += [Mi @ world_coords[i, :]]
    camera_coords = np.array(camera_coords)
    
    return camera_coords


def extrinsic_transform(world_coords,
                        theta_x=0, theta_y=0, theta_z=0,
                        origin_x=0, origin_y=0, origin_z=0):
    
    """
    origin_x (world coords center in camera coords)
    """
    
    Rx = np.array([
        [1, 0, 0],
        [0, np.cos(theta_x), -np.sin(theta_x)],
        [0, np.sin(theta_x), np.cos(theta_x)]
    ])
    
    Ry = np.array([
        [np.cos(theta_y), 0, np.sin(theta_y)],
        [0, 1, 0],
        [-np.sin(theta_y), 0, np.cos(theta_y)]
    ])
    
    Rz = np.array([
        [np.cos(theta_z), -np.sin(theta_z), 0],
        [np.sin(theta_z), np.cos(theta_z), 0],
        [0, 0, 1]
    ])
    
    rotation = Rx @ Ry @ Rz
    
    translation = np.array([origin_x, origin_y, origin_z])
    
    # see https://en.wikipedia.org/wiki/Camera_resectioning
    transform = np.zeros((4, 4))
    transform[:3, :3] = rotation
    transform[:3, 3] = translation
    transform[3, 3] = 1
        
    camera_coords = []
    for i in range(len(world_coords)):
        camera_coords += [transform @ world_coords[i, :]]
    camera_coords = np.array(camera_coords)
    
    return camera_coords


def limb_arc(x, r, h=1,
             method='resection', screen_dist=1,
             f=1, px=1, py=1, x0=0, y0=0,
             theta_x=0, theta_y=0, theta_z=0,
             origin_x=0, origin_y=0, origin_z=0
             ):
    
    # diffraction correction?
#     r = r * 1.2
        
    d = np.sqrt(h**2 + 2*h*r)
    theta = np.arccos(r / (r + h))

    xdcostheta = np.clip(x / (d * np.cos(theta)), -1, 1) # to avoid out of bounds
#     xdcostheta = x / (d * np.cos(theta))
    y_world = d * np.cos(np.arcsin(xdcostheta)) * np.sin(theta)
                   
    if method == 'screen':
        y_camera = y_world * screen_dist / np.sqrt(d**2 - y_world**2)
    elif method == 'resection':
        x_world = d * np.sin(np.arcsin(xdcostheta)) * np.cos(theta)
        z_world = d * np.cos(np.arcsin(xdcostheta)) * np.cos(theta)
        
        world_coords = np.ones((len(x), 4))
        world_coords[:, 0] = x_world
        world_coords[:, 1] = y_world
        world_coords[:, 2] = z_world
        # todo worth a 3d scatter demo of world coords?
        
        camera_coords = extrinsic_transform(world_coords,
                                            theta_x=theta_x, theta_y=theta_y, theta_z=theta_z,
                                            origin_x=origin_x, origin_y=origin_y, origin_z=origin_z)
        camera_coords = intrinsic_transform(camera_coords, f=f, px=px, py=py,
                                            x0=x0, y0=y0)
        
        y_camera = camera_coords[:, 1]
    
    return y_camera

y = limb_arc(np.arange(-100, 100), 1e6, method='resection')
plt.plot(np.arange(-100, 100), y)
plt.show()

# %%
x = np.linspace(-10, 10, 100)

for i, r in enumerate(np.logspace(1, 4, num=5)):
#     y = limb_arc(x, r, h=1, method='screen', screen_dist=1)
    y = limb_arc(x, r, method='resection', f=1, px=1, py=1, x0=0, y0=0)
    plt.plot(x, y, label=f'radius {r:.1e}', c='y', lw=i)
    
for i, r in enumerate(np.logspace(-2, -1, num=5)):
#     y = limb_arc(x, r=10, h=1, method='screen', screen_dist=r)
    y = limb_arc(x, r=10, method='resection', f=r, px=1, py=1, x0=0, y0=0)
    plt.plot(x, y, label=f'focal length {r:.1e}', c='b', lw=i)
    
for i, r in enumerate(np.logspace(-1, 1, num=5)):
    y = limb_arc(x, r=10, method='resection', f=1, px=1, py=r, x0=0, y0=0)
    plt.plot(x, y, label=f'ypix size {r:.1e}', c='k', lw=i)
    
plt.legend()
plt.show()
    
for i, theta in enumerate(np.linspace(0, np.pi/2, num=5)):
    y = limb_arc(x, r=10, method='resection', f=1, px=1, py=1, x0=0, y0=0,
                 theta_x=0, theta_y=0, theta_z=theta,
                 origin_x=0, origin_y=0, origin_z=0)
    plt.plot(x, y, label=f'theta z {theta:.1e}', c='y', lw=i)    

for i, theta in enumerate(np.linspace(-np.pi, np.pi, num=10)):
    y = limb_arc(x, r=10, method='resection', f=1, px=1, py=1, x0=0, y0=0,
                 theta_x=theta, theta_y=0, theta_z=0,
                 origin_x=0, origin_y=0, origin_z=0)
    plt.plot(x, y, label=f'theta x {theta:.1e}', c='b', lw=i) 
    
for i, d in enumerate(np.logspace(0, 2, num=5)):
    y = limb_arc(x, r=10, method='resection', f=1, px=1, py=1, x0=0, y0=0,
                 theta_x=0, theta_y=0, theta_z=0,
                 origin_x=d, origin_y=0, origin_z=0)
    plt.plot(x, y, label=f'origin x {d:.1e}', c='k', lw=i) 
    
plt.legend()
plt.show()

# %%
x = np.arange(im_arr.shape[1])
xc = x - int(len(x)*0.5)

y = limb_arc(xc, r=6.3e6, h=1) + 1500
plt.plot(x, y, c='y', lw=3)

plt.imshow(im_arr)
plt.show()

# %%
im_arr.shape
# Out:
# (2125, 8192, 3)

# %%
limb_arc(xc, r=6.3e6, h=1) + 1500
# Out:
# /var/folders/bt/hcx3fsms41nfk08g1d3xy8t40000gn/T/ipykernel_31802/1002530748.py:6: RuntimeWarning: invalid value encountered in sqrt
#   return a * np.sqrt(1 - b/c)
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
x = np.arange(im_arr.shape[1])
xc = x - int(len(x)*0.5)

y = limb_arc(xc, r=earth_r, h=iss_h, method='screen', screen_dist=1e9) + 1500
plt.plot(x, y-np.mean(y), c='y', lw=3)

# %%
iss_h = 418*1000 # up to 415-421km [418.552]
earth_r = 6.3e6

# %%
img = Image.open('demo/iss040e129950.jpg')
arry = img.getdata()
im_arr = np.fromstring(img.tobytes(), dtype=np.uint8)
im_arr = im_arr.reshape((img.size[1], img.size[0], 3))
# Out:
# /var/folders/bt/hcx3fsms41nfk08g1d3xy8t40000gn/T/ipykernel_31802/603171426.py:3: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   im_arr = np.fromstring(img.tobytes(), dtype=np.uint8)

# %%
6.3e6 / 8.5e4
# Out:
# 74.11764705882354

# %%
pix_ratio = im_arr.shape[1] / im_arr.shape[0]

# %%
limb_arc(x, r, h=h, method='screen', screen_dist=screen_dist)

# %%
cost_function(r=1e6, screen_dist=1e8, x_center=0, y_center=1500, 
              h=iss_h, second_deriv_sign=1)
# Out:
# array([-593.02729222, -592.17172478, -591.31655955, ...,  421.53820361,
#         420.68344045,  419.82827522])

# %%
m._strategy = 2

# %%
# resectioning 

target = breaks[:3500]
x = np.arange(len(target))

y = limb_arc(x, r=earth_r, h=iss_h, method='resection',
             f=1, px=1, py=3e-3, x0=0, y0=0,
             theta_x=np.pi, theta_y=0, theta_z=2e-4,
             origin_x=0, origin_y=809996, origin_z=0)
    
# rough guess
plt.plot(x, y, lw=3, c='k')
plt.scatter(x, target, c='y', lw=3, alpha=0.5)
plt.show()

def cost_function(r, h=iss_h,
                  f=1, px=1, py=3e-3, x0=0, y0=0,
                  theta_x=np.pi, theta_y=0, theta_z=2e-4,
                  origin_x=0, origin_y=809996, origin_z=0):
    
    y_pred = limb_arc(x, r=r, h=h,
                      f=f, px=px, py=py, x0=x0, y0=y0,
                      theta_x=theta_x, theta_y=theta_y, theta_z=theta_z,
                      origin_x=origin_x, origin_y=origin_y, origin_z=origin_z)

    return np.sum(abs(y_pred - target))
    
# def cost_function(r, screen_dist, x_center, y_center,
#                   h=iss_h, second_deriv_sign=-1):
#     y_pred = fancy_limb_arc(np.arange(len(target)), r, screen_dist, x_center, y_center,
#                             h=h, second_deriv_sign=second_deriv_sign)
#     return np.sum(abs(y_pred - target))

cost_function.errordef = Minuit.LEAST_SQUARES
# cost_function.errordef = Minuit.LIKELIHOOD

# m = Minuit(cost_function, r=earth_r, h=iss_h,
#            f=1, px=1, py=3e-3, x0=0, y0=0,
#            theta_x=np.pi, theta_y=0, theta_z=2e-4,
#            origin_x=0, origin_y=809996, origin_z=0)

m = Minuit(cost_function, r=earth_r, h=iss_h,
           f=1, px=1, py=1, x0=0, y0=0,
           theta_x=np.pi, theta_y=0, theta_z=0,
           origin_x=0, origin_y=0, origin_z=0)

# m.fixed = False # release all parameters
m.fixed["h"] = True
# m.fixed["x0"] = True
# m.fixed["y0"] = True
m.fixed["theta_y"] = True

m.limits["theta_x"] = (-np.pi, np.pi)
# m.limits["theta_y"] = (-np.pi, np.pi)
m.limits["theta_z"] = (-np.pi, np.pi)

m.limits["f"] = (0, None)
m.limits["px"] = (0, None)
m.limits["py"] = (0, None)

# m.limits["origin_x"] = (-np.pi, np.pi)
# m.limits["origin_y"] = (-np.pi, np.pi)
# m.limits["origin_z"] = (-np.pi, np.pi)

m.limits["r"] = (1e5, 1e8)
m.print_level = 2
m._tolerance = 1e-6
m._strategy = 2
m.errordef = 1
# m.tol = 1e-7

m.simplex(ncall=int(1e5))  # run optimiser
# m.simplex()
# m.minos()
print(m.values)

m.hesse()   # run covariance estimator
print(m.errors)

fit = m.values.to_dict()
fit
# Out:
# I SimplexBuilder    0 - FCN =        2811788525 Edm =       83312457.88 NCalls =     10
# I SimplexBuilder    1 - FCN =        2811788525 Edm =       56466479.41 NCalls =     12
# I SimplexBuilder    2 - FCN =        2618594220 Edm =       234332364.5 NCalls =     15
# I SimplexBuilder    3 - FCN =        2618594220 Edm =       222134946.1 NCalls =     16
# I SimplexBuilder    4 - FCN =        2618594220 Edm =       221286964.2 NCalls =     17
# I SimplexBuilder    5 - FCN =        2618594220 Edm =       221286964.2 NCalls =     18
# I SimplexBuilder    6 - FCN =        2618594220 Edm =       221286964.2 NCalls =     19
# I SimplexBuilder    7 - FCN =        2618594220 Edm =       221286964.2 NCalls =     20
# I SimplexBuilder    8 - FCN =        2618594220 Edm =       221286614.2 NCalls =     21
# I SimplexBuilder    9 - FCN =        2618594220 Edm =       207735229.5 NCalls =     22
# I SimplexBuilder   10 - FCN =        1991443396 Edm =       820345128.8 NCalls =     25
# I SimplexBuilder   11 - FCN =        1991443396 Edm =       801841360.6 NCalls =     26
# I SimplexBuilder   12 - FCN =        1991443396 Edm =       776454978.4 NCalls =     27
# I SimplexBuilder   13 - FCN =        1991443396 Edm =       760446866.9 NCalls =     28
# I SimplexBuilder   14 - FCN =        1991443396 Edm =       739645327.8 NCalls =     29
# I SimplexBuilder   15 - FCN =        1991443396 Edm =       713638326.6 NCalls =     30
# I SimplexBuilder   16 - FCN =        1991443396 Edm =       681009113.4 NCalls =     31
# I SimplexBuilder   17 - FCN =        1991443396 Edm =       639921431.2 NCalls =     32
# I SimplexBuilder   18 - FCN =       343204872.7 Edm =        2275389347 NCalls =     35
# I SimplexBuilder   19 - FCN =       343204872.7 Edm =        2093336838 NCalls =     36
# I SimplexBuilder   20 - FCN =       343204872.7 Edm =        2070105991 NCalls =     37
# I SimplexBuilder   21 - FCN =       343204872.7 Edm =        1994776938 NCalls =     38
# I SimplexBuilder   22 - FCN =       343204872.7 Edm =        1923154548 NCalls =     39
# I SimplexBuilder   23 - FCN =       343204872.7 Edm =        1845589149 NCalls =     40
# I SimplexBuilder   24 - FCN =       343204872.7 Edm =        1761642039 NCalls =     41
# I SimplexBuilder   25 - FCN =       343204872.7 Edm =        1671003769 NCalls =     42
# I SimplexBuilder   26 - FCN =       12215876.96 Edm =        1979227519 NCalls =     44
# I SimplexBuilder   27 - FCN =       10693838.39 Edm =        1360186582 NCalls =     46
# I SimplexBuilder   28 - FCN =       10693838.39 Edm =        1296139992 NCalls =     47
# I SimplexBuilder   29 - FCN =       10693838.39 Edm =        1082885084 NCalls =     48
# I SimplexBuilder   30 - FCN =       10693838.39 Edm =       911979983.5 NCalls =     49
# I SimplexBuilder   31 - FCN =       10693838.39 Edm =       719456135.2 NCalls =     50
# I SimplexBuilder   32 - FCN =       10693838.39 Edm =         525500690 NCalls =     51
# I SimplexBuilder   33 - FCN =       10693838.39 Edm =         340412651 NCalls =     53
# I SimplexBuilder   34 - FCN =       10693838.39 Edm =       332511034.4 NCalls =     55
# I SimplexBuilder   35 - FCN =       10693838.39 Edm =       290917000.9 NCalls =     57
# I SimplexBuilder   36 - FCN =       10693838.39 Edm =         147572662 NCalls =     59
# I SimplexBuilder   37 - FCN =       10693838.39 Edm =       129739547.6 NCalls =     61
# I SimplexBuilder   38 - FCN =       10693838.39 Edm =       51137157.31 NCalls =     63
# I SimplexBuilder   39 - FCN =       10693838.39 Edm =       50858705.84 NCalls =     65
# I SimplexBuilder   40 - FCN =       10693838.39 Edm =       37636986.01 NCalls =     67
# I SimplexBuilder   41 - FCN =       10693838.39 Edm =       34458982.46 NCalls =     69
# I SimplexBuilder   42 - FCN =       10693838.39 Edm =       32465746.11 NCalls =     71
# I SimplexBuilder   43 - FCN =       10693838.39 Edm =       25538520.82 NCalls =     73
# I SimplexBuilder   44 - FCN =       10693838.39 Edm =       6968641.417 NCalls =     75
# I SimplexBuilder   45 - FCN =       7432961.329 Edm =       9810255.534 NCalls =     77
# I SimplexBuilder   46 - FCN =       7432961.329 Edm =       8856269.916 NCalls =     79
# I SimplexBuilder   47 - FCN =       7111250.232 Edm =       6921248.272 NCalls =     81
# I SimplexBuilder   48 - FCN =       6983334.454 Edm =       6326716.152 NCalls =     83
# I SimplexBuilder   49 - FCN =        6462531.41 Edm =       5978071.258 NCalls =     85
# I SimplexBuilder   50 - FCN =       6105559.154 Edm =        6110317.81 NCalls =     87
# I SimplexBuilder   51 - FCN =       6105559.154 Edm =       5929785.646 NCalls =     89
# I SimplexBuilder   52 - FCN =       6105559.154 Edm =       5458980.747 NCalls =     91
# I SimplexBuilder   53 - FCN =       6105559.154 Edm =       4588279.232 NCalls =     93
# I SimplexBuilder   54 - FCN =       6045649.203 Edm =       1573390.464 NCalls =     95
# I SimplexBuilder   55 - FCN =       5366106.039 Edm =        2066855.29 NCalls =     97
# I SimplexBuilder   56 - FCN =       5366106.039 Edm =       1745144.194 NCalls =     99
# I SimplexBuilder   57 - FCN =       5261619.651 Edm =       1721714.804 NCalls =    101
# I SimplexBuilder   58 - FCN =       5261619.651 Edm =       1683103.667 NCalls =    103
# I SimplexBuilder   59 - FCN =       5244642.332 Edm =       1338246.437 NCalls =    105
# I SimplexBuilder   60 - FCN =       5114117.639 Edm =       1348413.771 NCalls =    107
# I SimplexBuilder   61 - FCN =       5114117.639 Edm =       1211376.372 NCalls =    108
# I SimplexBuilder   62 - FCN =       5114117.639 Edm =        991441.515 NCalls =    110
# I SimplexBuilder   63 - FCN =       5114117.639 Edm =       931531.5643 NCalls =    112
# I SimplexBuilder   64 - FCN =       5102204.112 Edm =       778122.3572 NCalls =    114
# I SimplexBuilder   65 - FCN =       5087358.258 Edm =       408346.3229 NCalls =    116
# I SimplexBuilder   66 - FCN =       4984622.081 Edm =       403013.3626 NCalls =    118
# I SimplexBuilder   67 - FCN =       4984622.081 Edm =       381483.9578 NCalls =    120
# I SimplexBuilder   68 - FCN =       4972446.184 Edm =       289173.4662 NCalls =    122
# I SimplexBuilder   69 - FCN =       4939167.267 Edm =       305475.0651 NCalls =    124
# I SimplexBuilder   70 - FCN =       4939167.267 Edm =       214772.5981 NCalls =    126
# I SimplexBuilder   71 - FCN =        4917583.72 Edm =        235590.122 NCalls =    128
# I SimplexBuilder   72 - FCN =        4917583.72 Edm =       196533.9186 NCalls =    130
# I SimplexBuilder   73 - FCN =        4917583.72 Edm =       184620.3913 NCalls =    132
# I SimplexBuilder   74 - FCN =       4912616.697 Edm =       174741.5615 NCalls =    134
# I SimplexBuilder   75 - FCN =       4912616.697 Edm =       78294.19718 NCalls =    136
# I SimplexBuilder   76 - FCN =       4890749.562 Edm =       93872.51888 NCalls =    138
# I SimplexBuilder   77 - FCN =       4890749.562 Edm =        81696.6224 NCalls =    140
# I SimplexBuilder   78 - FCN =       4886862.698 Edm =       71090.07685 NCalls =    142
# I SimplexBuilder   79 - FCN =       4886753.446 Edm =       52413.82086 NCalls =    144
# I SimplexBuilder   80 - FCN =       4880009.073 Edm =       56789.09949 NCalls =    146
# I SimplexBuilder   81 - FCN =       4880009.073 Edm =       40563.04393 NCalls =    148
# I SimplexBuilder   82 - FCN =       4876844.117 Edm =       40739.60301 NCalls =    150
# I SimplexBuilder   83 - FCN =       4876844.117 Edm =       38255.93717 NCalls =    152
# I SimplexBuilder   84 - FCN =       4875679.323 Edm =       36937.37396 NCalls =    154
# I SimplexBuilder   85 - FCN =       4875679.323 Edm =       16602.74938 NCalls =    156
# I SimplexBuilder   86 - FCN =       4871030.082 Edm =       19719.48006 NCalls =    158
# I SimplexBuilder   87 - FCN =       4871030.082 Edm =       15832.61595 NCalls =    160
# I SimplexBuilder   88 - FCN =       4869842.693 Edm =       16910.75295 NCalls =    162
# I SimplexBuilder   89 - FCN =       4869842.693 Edm =       12198.74161 NCalls =    164
# I SimplexBuilder   90 - FCN =       4868979.676 Edm =       11029.39653 NCalls =    166
# I SimplexBuilder   91 - FCN =       4868894.941 Edm =       8214.611318 NCalls =    168
# I SimplexBuilder   92 - FCN =       4867937.659 Edm =       8906.458924 NCalls =    170
# I SimplexBuilder   93 - FCN =       4867937.659 Edm =       8101.147969 NCalls =    172
# I SimplexBuilder   94 - FCN =       4867700.357 Edm =       7978.965623 NCalls =    174
# I SimplexBuilder   95 - FCN =       4867700.357 Edm =       3579.514792 NCalls =    176
# I SimplexBuilder   96 - FCN =       4866757.144 Edm =       4272.938031 NCalls =    178
# I SimplexBuilder   97 - FCN =       4866757.144 Edm =       3738.566922 NCalls =    180
# I SimplexBuilder   98 - FCN =       4866690.887 Edm =       3151.805365 NCalls =    182
# I SimplexBuilder   99 - FCN =       4866586.074 Edm =       2393.601887 NCalls =    184
# I SimplexBuilder  100 - FCN =       4866372.287 Edm =       2522.653337 NCalls =    186
# I SimplexBuilder  101 - FCN =       4866372.287 Edm =       1849.224606 NCalls =    188
# I SimplexBuilder  102 - FCN =       4866215.971 Edm =       1767.173395 NCalls =    190
# I SimplexBuilder  103 - FCN =       4866103.702 Edm =       1833.956894 NCalls =    192
# I SimplexBuilder  104 - FCN =       4866103.702 Edm =       1596.655364 NCalls =    194
# I SimplexBuilder  105 - FCN =       4866103.702 Edm =        838.122756 NCalls =    196
# I SimplexBuilder  106 - FCN =       4865942.521 Edm =       814.6231683 NCalls =    198
# I SimplexBuilder  107 - FCN =       4865928.305 Edm =       762.5827431 NCalls =    200
# I SimplexBuilder  108 - FCN =       4865888.941 Edm =       697.1332932 NCalls =    202
# I SimplexBuilder  109 - FCN =       4865888.941 Edm =       491.3348283 NCalls =    204
# I SimplexBuilder  110 - FCN =       4865827.845 Edm =        544.442489 NCalls =    206
# I SimplexBuilder  111 - FCN =       4865827.845 Edm =       416.6520893 NCalls =    208
# I SimplexBuilder  112 - FCN =       4865799.971 Edm =       415.9999486 NCalls =    210
# I SimplexBuilder  113 - FCN =       4865799.971 Edm =       333.8824666 NCalls =    212
# I SimplexBuilder  114 - FCN =       4865776.961 Edm =       326.7407089 NCalls =    214
# I SimplexBuilder  115 - FCN =       4865776.961 Edm =       165.5597268 NCalls =    216
# I SimplexBuilder  116 - FCN =       4865741.269 Edm =         187.03534 NCalls =    218
# I SimplexBuilder  117 - FCN =       4865741.269 Edm =       151.5156262 NCalls =    220
# I SimplexBuilder  118 - FCN =        4865729.21 Edm =        159.730903 NCalls =    222
# I SimplexBuilder  119 - FCN =        4865729.21 Edm =        113.400287 NCalls =    224
# I SimplexBuilder  120 - FCN =       4865721.293 Edm =       106.5521669 NCalls =    226
# I SimplexBuilder  121 - FCN =       4865720.144 Edm =       88.58949989 NCalls =    228
# I SimplexBuilder  122 - FCN =       4865714.185 Edm =       85.78665422 NCalls =    230
# I SimplexBuilder  123 - FCN =       4865714.184 Edm =       70.43641397 NCalls =    232
# I SimplexBuilder  124 - FCN =       4865709.146 Edm =       67.81474911 NCalls =    234
# I SimplexBuilder  125 - FCN =       4865709.146 Edm =       33.39853945 NCalls =    236
# I SimplexBuilder  126 - FCN =       4865700.193 Edm =       41.07591016 NCalls =    238
# I SimplexBuilder  127 - FCN =       4865700.193 Edm =       35.77608696 NCalls =    240
# I SimplexBuilder  128 - FCN =        4865699.37 Edm =       29.84002585 NCalls =    242
# I SimplexBuilder  129 - FCN =       4865698.657 Edm =       22.63602446 NCalls =    244
# I SimplexBuilder  130 - FCN =       4865696.308 Edm =       23.83603923 NCalls =    246
# I SimplexBuilder  131 - FCN =       4865696.308 Edm =       17.87697187 NCalls =    248
# I SimplexBuilder  132 - FCN =       4865694.844 Edm =        19.3400941 NCalls =    250
# I SimplexBuilder  133 - FCN =       4865694.844 Edm =        14.4201732 NCalls =    252
# I SimplexBuilder  134 - FCN =       4865693.771 Edm =       15.37498483 NCalls =    254
# I SimplexBuilder  135 - FCN =       4865693.771 Edm =       8.040011338 NCalls =    256
# I SimplexBuilder  136 - FCN =       4865692.387 Edm =       7.806345547 NCalls =    258
# I SimplexBuilder  137 - FCN =        4865692.27 Edm =       7.100350997 NCalls =    260
# I SimplexBuilder  138 - FCN =       4865691.868 Edm =       6.788995195 NCalls =    262
# I SimplexBuilder  139 - FCN =       4865691.868 Edm =       4.820514524 NCalls =    264
# I SimplexBuilder  140 - FCN =       4865691.326 Edm =       4.981606512 NCalls =    266
# I SimplexBuilder  141 - FCN =       4865691.326 Edm =       4.062243605 NCalls =    268
# I SimplexBuilder  142 - FCN =       4865691.055 Edm =       3.788999099 NCalls =    270
# I SimplexBuilder  143 - FCN =       4865691.055 Edm =       3.309938631 NCalls =    272
# I SimplexBuilder  144 - FCN =       4865690.886 Edm =       2.885408242 NCalls =    274
# I SimplexBuilder  145 - FCN =       4865690.836 Edm =       1.551128048 NCalls =    276
# I SimplexBuilder  146 - FCN =        4865690.48 Edm =       1.790062365 NCalls =    278
# I SimplexBuilder  147 - FCN =        4865690.48 Edm =       1.468302102 NCalls =    280
# I SimplexBuilder  148 - FCN =       4865690.381 Edm =       1.486267748 NCalls =    282
# I SimplexBuilder  149 - FCN =       4865690.381 Edm =       1.043786368 NCalls =    284
# I SimplexBuilder  150 - FCN =       4865690.288 Edm =       1.037699699 NCalls =    286
# I SimplexBuilder  151 - FCN =       4865690.288 Edm =      0.8236599714 NCalls =    288
# I SimplexBuilder  152 - FCN =       4865690.223 Edm =       0.832178982 NCalls =    290
# I SimplexBuilder  153 - FCN =       4865690.223 Edm =      0.6626981618 NCalls =    292
# I SimplexBuilder  154 - FCN =       4865690.176 Edm =      0.6597003248 NCalls =    294
# I SimplexBuilder  155 - FCN =       4865690.176 Edm =      0.3294019867 NCalls =    296
# I SimplexBuilder  156 - FCN =         4865690.1 Edm =      0.3792422628 NCalls =    298
# I SimplexBuilder  157 - FCN =         4865690.1 Edm =      0.3264725041 NCalls =    300
# I SimplexBuilder  158 - FCN =       4865690.085 Edm =      0.2965803081 NCalls =    302
# I SimplexBuilder  159 - FCN =       4865690.085 Edm =      0.2088863729 NCalls =    304
# I SimplexBuilder  160 - FCN =       4865690.059 Edm =      0.2296466585 NCalls =    306
# I SimplexBuilder  161 - FCN =       4865690.059 Edm =      0.1768161952 NCalls =    308
# I SimplexBuilder  162 - FCN =       4865690.047 Edm =      0.1764711179 NCalls =    310
# I SimplexBuilder  163 - FCN =       4865690.047 Edm =      0.1415869435 NCalls =    312
# I SimplexBuilder  164 - FCN =       4865690.037 Edm =      0.1393622346 NCalls =    314
# I SimplexBuilder  165 - FCN =       4865690.037 Edm =     0.07132932544 NCalls =    316
# I SimplexBuilder  166 - FCN =       4865690.022 Edm =     0.07838424575 NCalls =    318
# I SimplexBuilder  167 - FCN =       4865690.022 Edm =     0.06426590588 NCalls =    320
# I SimplexBuilder  168 - FCN =       4865690.017 Edm =     0.06817464344 NCalls =    322
# I SimplexBuilder  169 - FCN =       4865690.017 Edm =     0.04787852801 NCalls =    324
# I SimplexBuilder  170 - FCN =       4865690.013 Edm =     0.04536281433 NCalls =    326
# I SimplexBuilder  171 - FCN =       4865690.013 Edm =     0.03764951788 NCalls =    328
# I SimplexBuilder  172 - FCN =        4865690.01 Edm =     0.03633399587 NCalls =    330
# I SimplexBuilder  173 - FCN =        4865690.01 Edm =     0.03012971953 NCalls =    332
# I SimplexBuilder  174 - FCN =       4865690.008 Edm =     0.02864401601 NCalls =    334
# I SimplexBuilder  175 - FCN =       4865690.008 Edm =     0.01396774128 NCalls =    336
# I SimplexBuilder  176 - FCN =       4865690.004 Edm =     0.01773732807 NCalls =    338
# I SimplexBuilder  177 - FCN =       4865690.004 Edm =     0.01535399444 NCalls =    340
# I SimplexBuilder  178 - FCN =       4865690.004 Edm =     0.01264227927 NCalls =    342
# I SimplexBuilder  179 - FCN =       4865690.004 Edm =    0.009593509138 NCalls =    344
# I SimplexBuilder  180 - FCN =       4865690.003 Edm =     0.01010465994 NCalls =    346
# I SimplexBuilder  181 - FCN =       4865690.003 Edm =    0.007617888972 NCalls =    348
# I SimplexBuilder  182 - FCN =       4865690.002 Edm =    0.008151711896 NCalls =    350
# I SimplexBuilder  183 - FCN =       4865690.002 Edm =    0.006116254255 NCalls =    352
# I SimplexBuilder  184 - FCN =       4865690.002 Edm =    0.006493338384 NCalls =    354
# I SimplexBuilder  185 - FCN =       4865690.002 Edm =    0.003440539353 NCalls =    356
# I SimplexBuilder  186 - FCN =       4865690.001 Edm =    0.003252057359 NCalls =    358
# I SimplexBuilder  187 - FCN =       4865690.001 Edm =    0.003050368279 NCalls =    360
# I SimplexBuilder  188 - FCN =       4865690.001 Edm =    0.002875906415 NCalls =    362
# I SimplexBuilder  189 - FCN =       4865690.001 Edm =    0.002036334015 NCalls =    364
# I SimplexBuilder  190 - FCN =       4865690.001 Edm =    0.002112474293 NCalls =    366
# I SimplexBuilder  191 - FCN =       4865690.001 Edm =     0.00169393234 NCalls =    368
# I SimplexBuilder  192 - FCN =           4865690 Edm =    0.001619835384 NCalls =    370
# I SimplexBuilder  193 - FCN =           4865690 Edm =     0.00135417562 NCalls =    372
# I SimplexBuilder  194 - FCN =           4865690 Edm =    0.001283274032 NCalls =    374
# I SimplexBuilder  195 - FCN =           4865690 Edm =   0.0006557516754 NCalls =    376
# I SimplexBuilder  196 - FCN =           4865690 Edm =   0.0007612714544 NCalls =    378
# I SimplexBuilder  197 - FCN =           4865690 Edm =   0.0006363941357 NCalls =    380
# I SimplexBuilder  198 - FCN =           4865690 Edm =   0.0006210822612 NCalls =    382
# I SimplexBuilder  199 - FCN =           4865690 Edm =   0.0004265028983 NCalls =    384
# I SimplexBuilder  200 - FCN =           4865690 Edm =   0.0004540812224 NCalls =    386
# I SimplexBuilder  201 - FCN =           4865690 Edm =   0.0003444626927 NCalls =    388
# I SimplexBuilder  202 - FCN =           4865690 Edm =   0.0003650682047 NCalls =    390
# I SimplexBuilder  203 - FCN =           4865690 Edm =   0.0002792794257 NCalls =    392
# I SimplexBuilder  204 - FCN =           4865690 Edm =   0.0002884157002 NCalls =    394
# I SimplexBuilder  205 - FCN =           4865690 Edm =   0.0001447368413 NCalls =    396
# I SimplexBuilder  206 - FCN =           4865690 Edm =   0.0001578545198 NCalls =    398
# I SimplexBuilder  207 - FCN =           4865690 Edm =   0.0001335777342 NCalls =    400
# I SimplexBuilder  208 - FCN =           4865690 Edm =   0.0001321341842 NCalls =    402
# I SimplexBuilder  209 - FCN =           4865690 Edm =    9.42517072e-05 NCalls =    404
# I SimplexBuilder  210 - FCN =           4865690 Edm =   9.148474783e-05 NCalls =    406
# I SimplexBuilder  211 - FCN =           4865690 Edm =   7.775612175e-05 NCalls =    408
# I SimplexBuilder  212 - FCN =           4865690 Edm =   6.993673742e-05 NCalls =    410
# I SimplexBuilder  213 - FCN =           4865690 Edm =   6.270781159e-05 NCalls =    412
# I SimplexBuilder  214 - FCN =           4865690 Edm =   5.545467138e-05 NCalls =    414
# I SimplexBuilder  215 - FCN =           4865690 Edm =   2.853292972e-05 NCalls =    416
# I SimplexBuilder  216 - FCN =           4865690 Edm =   3.560911864e-05 NCalls =    418
# I SimplexBuilder  217 - FCN =           4865690 Edm =   3.009662032e-05 NCalls =    420
# I SimplexBuilder  218 - FCN =           4865690 Edm =   2.636760473e-05 NCalls =    422
# I SimplexBuilder  219 - FCN =           4865690 Edm =   1.904368401e-05 NCalls =    424
# I SimplexBuilder  220 - FCN =           4865690 Edm =   2.018082887e-05 NCalls =    426
# I SimplexBuilder  221 - FCN =           4865690 Edm =   1.582223922e-05 NCalls =    428
# I SimplexBuilder  222 - FCN =           4865690 Edm =   1.558102667e-05 NCalls =    430
# I SimplexBuilder  223 - FCN =           4865690 Edm =    1.25169754e-05 NCalls =    432
# I SimplexBuilder  224 - FCN =           4865690 Edm =   1.251883805e-05 NCalls =    434
# I SimplexBuilder  225 - FCN =           4865690 Edm =   6.825663149e-06 NCalls =    436
# I SimplexBuilder  226 - FCN =           4865690 Edm =   6.492249668e-06 NCalls =    438
# I SimplexBuilder  227 - FCN =           4865690 Edm =   6.029382348e-06 NCalls =    440
# I SimplexBuilder  228 - FCN =           4865690 Edm =   5.915760994e-06 NCalls =    442
# I SimplexBuilder  229 - FCN =           4865690 Edm =   4.023313522e-06 NCalls =    444
# I SimplexBuilder  230 - FCN =           4865690 Edm =    4.30829823e-06 NCalls =    446
# I SimplexBuilder  231 - FCN =           4865690 Edm =   3.259629011e-06 NCalls =    448
# I SimplexBuilder  232 - FCN =           4865690 Edm =   3.466382623e-06 NCalls =    450
# I SimplexBuilder  233 - FCN =           4865690 Edm =   2.657994628e-06 NCalls =    452
# I SimplexBuilder  234 - FCN =           4865690 Edm =   2.725981176e-06 NCalls =    454
# I SimplexBuilder  235 - FCN =           4865690 Edm =    1.37835741e-06 NCalls =    456
# I SimplexBuilder  236 - FCN =           4865690 Edm =   1.490116119e-06 NCalls =    458
# I SimplexBuilder  237 - FCN =           4865690 Edm =   1.269392669e-06 NCalls =    460
# I SimplexBuilder  238 - FCN =           4865690 Edm =   1.250766218e-06 NCalls =    462
# I SimplexBuilder  239 - FCN =           4865690 Edm =   8.940696716e-07 NCalls =    464
# I SimplexBuilder Final iteration FCN =           4865690 Edm =   9.750947356e-07 NCalls =    467
# <ValueView r=7027454.5543443 h=418000.0 f=2.3852447794681098e-18 px=1.1853686139294273 py=1.3397038006939033 x0=0.0 y0=0.0 theta_x=3.0563371970953384 theta_y=0.0 theta_z=-0.68166045251616 origin_x=2.10891968914654 origin_y=3.2416815431872514 origin_z=2.3354718310059397>
# W MnHesse 2nd derivative zero for parameter r ; MnHesse fails and will return diagonal matrix
# <ErrorView r=27.490973880980164 h=4180.0 f=1.751513454943416e-09 px=7.158318616307113e-06 py=1.3026405680127695e-05 x0=0.1 y0=0.1 theta_x=1.1519191130959783e-05 theta_y=0.1 theta_z=8.744210583772061e-05 origin_x=7.701613531692994e-05 origin_y=0.00013248571236018294 origin_z=8.063594486360034e-05>
# {'r': 7027454.5543443,
#  'h': 418000.0,
#  'f': 2.3852447794681098e-18,
#  'px': 1.1853686139294273,
#  'py': 1.3397038006939033,
#  'x0': 0.0,
#  'y0': 0.0,
#  'theta_x': 3.0563371970953384,
#  'theta_y': 0.0,
#  'theta_z': -0.68166045251616,
#  'origin_x': 2.10891968914654,
#  'origin_y': 3.2416815431872514,
#  'origin_z': 2.3354718310059397}

# %%
# fancy version

# target = breaks[:3500]

# def fancy_limb_arc(x, r, screen_dist, x_center, y_center,
#                    h=iss_h, second_deriv_sign=-1):
# #     x = np.arange(len(y))
# #     x = x - int(len(x)*0.5) - x_center
#     arc = limb_arc(x - x_center, r=r, h=h,
#                    method='screen', screen_dist=screen_dist)
#     arc = second_deriv_sign * (arc - np.nanmean(arc)) + y_center
        
#     return arc
    
# # y = fancy_limb_arc(np.arange(len(target)), earth_r, 1e9, 1700, 1400, h=iss_h, second_deriv_sign=-1)
# # plt.plot(np.arange(len(target)), y, lw=3, c='k')
# # plt.scatter(np.arange(len(target)), target, c='y', lw=3, alpha=0.5)

# def cost_function(r, screen_dist, x_center, y_center,
#                   h=iss_h, second_deriv_sign=-1):
#     y_pred = fancy_limb_arc(np.arange(len(target)), r, screen_dist, x_center, y_center,
#                             h=h, second_deriv_sign=second_deriv_sign)
#     return np.sum(abs(y_pred - target))

# cost_function.errordef = Minuit.LEAST_SQUARES

# m = Minuit(cost_function, r=1e6, screen_dist=1, x_center=len(target)*0.5, y_center=1500, 
#            h=iss_h, second_deriv_sign=-1)

# # m.fixed = False # release all parameters
# m.fixed["second_deriv_sign"] = True
# m.fixed["h"] = True
# m.limits["x_center"] = (0, len(target))
# m.limits["y_center"] = (1200, 1700)
# m.limits["screen_dist"] = (1e-3, 1e12)
# m.limits["r"] = (1e5, 1e8)
# m.print_level = 1

# m.simplex()  # run optimiser
# print(m.values)  # x: 2, y: 3, z: 4

# m.hesse()   # run covariance estimator
# print(m.errors)  # x: 1, y: 1, z: 1

# fit = m.values.to_dict()
# fit
# Out:
# <ValueView r=452031.54663343215 screen_dist=1688025.6394062063 x_center=1937.648311526146 y_center=1395.7454925790496 h=418000.0 second_deriv_sign=-1.0>
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.0170013
# <ErrorView r=3364.0392335882934 screen_dist=42428.127557179774 x_center=2.1533894647132 y_center=0.07077386269486396 h=4180.0 second_deriv_sign=-0.01>
# {'r': 452031.54663343215,
#  'screen_dist': 1688025.6394062063,
#  'x_center': 1937.648311526146,
#  'y_center': 1395.7454925790496,
#  'h': 418000.0,
#  'second_deriv_sign': -1.0}

# %%
fit['r'], earth_r
# Out:
# (7027454.5543443, 6300000.0)

# %%
y = limb_arc(x, **fit)

plt.imshow(im_arr, origin='lower')
plt.plot(np.arange(len(target)), y, lw=3, c='w')
plt.scatter(np.arange(len(target)), target, c='y', lw=3, alpha=0.1)

# %%
# y = fancy_limb_arc(np.arange(len(target)), fit['r'], fit['screen_dist'], fit['x_center'], fit['y_center'],
#                    h=iss_h, second_deriv_sign=-1)


# plt.imshow(im_arr, origin='lower')
# plt.plot(np.arange(len(target)), y, lw=3, c='k')
# plt.scatter(np.arange(len(target)), target, c='y', lw=3, alpha=0.1)

# %%
def intrinsic_transform(x_world, y_world, z_world, f=1, px=1, py=1, x0=0, y0=0):
    Mi = np.array([
        [f/px, 0, x0, 0],
        [0, f/py, y0, 0],
        [0, 0, 1, 0]
    ])
    
    world_coords = np.array([x_world, y_world, z_world, 1])
    
    camera_coords = np.matmul(Mi, world_coords)
    
    return camera_coords



intrinsic_transform(10, 10, 10, px=1, py=2)
# Out:
# array([10.,  5., 10.])

# %%
y
# Out:
# array([1488.74698407, 1488.61345215, 1488.47998915, ..., 1443.15094068,
#        1443.25846809, 1443.36606443])

# %%
grad = np.log10(abs(np.gradient(im_arr.sum(axis=2), axis=0)))
# Out:
# /var/folders/bt/hcx3fsms41nfk08g1d3xy8t40000gn/T/ipykernel_31802/4206736744.py:1: RuntimeWarning: divide by zero encountered in log10
#   grad = np.log10(abs(np.gradient(im_arr.sum(axis=2), axis=0)))

# %%
plt.imshow(grad)
plt.show()

# %%
plt.imshow(grad, origin='lower')

breaks = find_break(grad)
plt.scatter(np.arange(grad.shape[1]), breaks)
plt.show()

# %%
plt.imshow(im_arr)

x = np.arange(im_arr.shape[1])
xc = x - int(len(x)*0.5)
y = limb_arc(xc / pix_ratio, r=8.5e4, h=iss_h)
ye = limb_arc(xc, r=earth_r*1.2, h=iss_h, method='screen', screen_dist=1e9)

# plt.plot(x - 200, np.mean(y) - y + 1450, c='y', lw=3)
plt.plot(x - 200, np.mean(ye) - ye + 1450, c='b', lw=3)

plt.show()

# %%
plt.imshow(im_arr)

# %%
np.mean(ye)
# Out:
# 337103949.9825986

# %%
x = np.arange(im_arr.shape[1])
xc = x - int(len(x)*0.5)
y = limb_arc(xc, r=earth_r, h=iss_h)
plt.plot(x, y-np.mean(y)+1500, c='y', lw=3)

# %%
true_coefs = torch.tensor([[1.], [2.]])

data = torch.randn((2, 1))

dim = 1

labels = dist.Bernoulli(logits=(true_coefs * data).sum(-1)).sample()


def dummy(x, y, n=1):
    return 2*x + 5*y


def model(data):

#     coefs_mean = torch.zeros(dim)
    coeffs_mean = torch.zeros((2, dim))
    coeffs_std = torch.ones(2, dim)

#     coefs = pyro.sample('beta', dist.Normal(coefs_mean, torch.ones(3)))
#     coefs = pyro.sample('beta', dist.Normal(coefs_mean, torch.ones(2, dim)))

#     y = pyro.sample('y', dist.Bernoulli(logits=(coefs * data).sum(-1)), obs=labels)
    coeffs = pyro.sample('normal', dist.Normal(coeffs_mean, coeffs_std))
    y = pyro.sample('y', dummy(*coeffs), obs=labels)

    return y

# hmc_kernel = HMC(model, step_size=0.0855, num_steps=4)

# mcmc = MCMC(hmc_kernel, num_samples=500, warmup_steps=100)

# mcmc_run = mcmc.run(data)

# mcmc.get_samples()['beta'].mean()  
# # torch.tensor([ 0.9819,  1.9258,  2.9737])
# posterior = mcmc_run.marginal('beta').empirical['beta']
# posterior.mean  # doctest: +SKIP
# # tensor([ 0.9819,  1.9258,  2.9737])

hmc_kernel = HMC(model, step_size=0.0855, num_steps=4)
mcmc = MCMC(hmc_kernel, num_samples=1000, warmup_steps=100)
mcmc.run(data)
mcmc.summary()
# posterior = mcmc_run.marginal('beta').empirical['beta']
# posterior.mean  # doctest: +SKIP

# %%
def dummy(x, y, n=1):
    return 2*x + 5*y

thing = pyro.sample('beta', dist.Normal(torch.zeros((2, dim)), torch.ones(2, dim)))
# x, y = thing
dummy(*thing)
# Out:
# tensor([-1.4693])

# %%
dist.Bernoulli(logits=(torch.zeros((2, dim)) * data).sum(-1)).sample()
# Out:
# tensor([0., 0.])

# %%
labels
# Out:
# tensor([0., 1.])

# %%
dist.Bernoulli(logits=(true_coefs * data).sum(-1)).sample()
# Out:
# tensor([1., 1.])

# %%
true_coefs = torch.tensor([1., 2., 3.])
data = torch.randn(2000, 3)
dim = 3
labels = dist.Bernoulli(logits=(true_coefs * data).sum(-1)).sample()
def model(data):
    coefs_mean = torch.zeros(dim)
    coefs = pyro.sample('beta', dist.Normal(coefs_mean, torch.ones(3)))
    y = pyro.sample('y', dist.Bernoulli(logits=(coefs * data).sum(-1)), obs=labels)
    return y
hmc_kernel = HMC(model, step_size=0.0855, num_steps=4)
mcmc = MCMC(hmc_kernel, num_samples=1000, warmup_steps=100)
mcmc.run(data)
mcmc.summary()
# mcmc_run = mcmc.run(data)
# posterior = mcmc.marginal('beta').empirical['beta']
# posterior.mean  # doctest: +SKIP
# tensor([ 0.9819,  1.9258,  2.9737])
# Out:
# Sample: 100%|███████████████████████████████████████| 1100/1100 [00:02, 538.48it/s, step size=5.92e-01, acc. prob=0.930]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#    beta[0]      1.12      0.08      1.12      0.98      1.24    111.27      1.01
#    beta[1]      2.04      0.10      2.04      1.87      2.20     43.13      1.00
#    beta[2]      3.08      0.14      3.09      2.85      3.30     27.30      1.00
#
# Number of divergences: 0

# %%
MCMC(hmc_kernel, num_samples=500, warmup_steps=100).run(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [656], in <cell line: 1>()
# ----> 1 MCMC(hmc_kernel, num_samples=500, warmup_steps=100).run(data)
#
# File ~/Projects/bogs/planet-ruler/venv/lib/python3.9/site-packages/pyro/infer/mcmc/api.py:476, in MCMC.__init__(self, kernel, num_samples, warmup_steps, initial_params, num_chains, hook_fn, mp_context, disable_progbar, disable_validation, transforms, save_params)
#     474 if save_params is not None:
#     475     kernel.save_params = save_params
# --> 476 self._validate_kernel(initial_params)
#     477 parallel = False
#     478 if num_chains > 1:
#     479     # check that initial_params is different for each chain
#
# File ~/Projects/bogs/planet-ruler/venv/lib/python3.9/site-packages/pyro/infer/mcmc/api.py:389, in AbstractMCMC._validate_kernel(self, initial_params)
#     384 if (
#     385     isinstance(self.kernel, (HMC, NUTS))
#     386     and self.kernel.potential_fn is not None
#     387 ):
#     388     if initial_params is None:
# --> 389         raise ValueError(
#     390             "Must provide valid initial parameters to begin sampling"
#     391             " when using `potential_fn` in HMC/NUTS kernel."
#     392         )
#
# ValueError: Must provide valid initial parameters to begin sampling when using `potential_fn` in HMC/NUTS kernel.

# %%
dist.Bernoulli(logits=(coefs * data).sum(-1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [646], in <cell line: 1>()
# ----> 1 dist.Bernoulli(logits=(coefs * data).sum(-1))
#
# NameError: name 'coefs' is not defined

# %%
import torch
from pyro.infer.mcmc.api import HMC, MCMC
import pyro.distributions as dist

# %%
import torch.distributions as dist

# %%
import pyro

# %%
y_pred = limb_arc(x, r=r, h=h,
                  f=f, px=px, py=py, x0=x0, y0=y0,
                  theta_x=theta_x, theta_y=theta_y, theta_z=theta_z,
                  origin_x=origin_x, origin_y=origin_y, origin_z=origin_z)

# %%
dim = 13

labels = target

def model(data):

    coefs_mean = torch.zeros(dim)

    coefs = pyro.sample('beta', dist.Normal(coefs_mean, torch.ones(3)))

    y = pyro.sample('y', dist.Bernoulli(logits=(coefs * data).sum(-1)), obs=labels)
    y = pyro.sample('y', limb_arc(**kwargs), obs=labels)

    return y

hmc_kernel = HMC(model, step_size=0.0855, num_steps=4)

mcmc = MCMC(hmc_kernel, num_samples=500, warmup_steps=100)

mcmc.run(data)

mcmc.get_samples()['beta'].mean(0)  
torch.tensor([ 0.9819,  1.9258,  2.9737])
# Out:
# <module 'pyro.infer.mcmc.api' from '/Users/banderson/Projects/bogs/planet-ruler/venv/lib/python3.9/site-packages/pyro/infer/mcmc/api.py'>

# %%
target
# Out:
# array([1486, 1486, 1486, ..., 1443, 1443, 1443])
